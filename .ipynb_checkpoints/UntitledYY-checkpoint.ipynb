# %%
import pandas as pd
df = pd.read_excel('birds_dataset_with_ranks_new.xlsx') # 'static/Data/birds_dataset_with_ranks_new.xlsx')
# print(df)

# %%
df.head()
# Out:
#    bird_id        theme        head       eyes        body        tail  \
# 0        1    cyberbird   cyberbird  cyberbird   cyberbird   cyberbird
# 1        2     rmrkpink       1f916      1f60e       1f916       1f916
# 2        3     eggplant  1f32a-fe0f      1f60e  1f32a-fe0f  1f32a-fe0f
# 3        4  oddworldabe       1f30b      1f62c       1f30b       1f30b
# 4        5    bandicoot       1f525      1f976       1f525       1f525
#
#      wingLeft   wingRight        feet   beak  trait_score  trait_rank  \
# 0   cyberbird   cyberbird   cyberbird   var2     3.898092           4
# 1       1f916       1f916       1f916  1f60e     2.187958          72
# 2  1f32a-fe0f  1f32a-fe0f  1f32a-fe0f  1f60e     2.742904          17
# 3       1f30b       1f30b       1f30b  1f62c     2.449527          43
# 4       1f525       1f525       1f525  1f976     2.296878          61
#
#    set_score  set_rank  edition_score  edition_rank  weighted_score  \
# ...

# %%
sorted_Score = df['week_trade_score'].tolist()
# print(len(sorted_Score))

# %%
#Making data set as the following:
#Key:Value
#bird_id: ()
sorted_Bird_Ids = df['bird_id'].tolist()
# print(len(sorted_Bird_Ids))

# %%
dict_plot_graph = dict(zip(sorted_Bird_Ids,sorted_Score))

# %%
dict_plot_graph
# Out:
# {1: 6.488415561512897,
#  2: 5.202100106415225,
#  3: 5.6195150533110185,
#  4: 5.398845597126139,
#  5: 5.284027001520672,
#  6: 5.122265426133959,
#  7: 5.8616827626699015,
#  8: 5.5021787462271705,
#  9: 5.3630555594150096,
#  10: 3.2548816799852704,
#  11: 3.512563325981266,
#  12: 3.5736602278943908,
#  13: 3.38832664102346,
#  14: 3.5420034052298397,
#  15: 4.008016339733195,
#  16: 3.618784139013056,
#  17: 4.232276408674717,
#  18: 3.982646779538257,
#  19: 3.2032236759401225,
#  20: 3.2697033284809733,
#  21: 3.3126429175573566,
#  22: 4.538387901739987,
#  23: 3.2836397129903334,
#  24: 3.446312789308561,
#  25: 3.713324882142705,
#  26: 3.6577577737067153,
#  27: 3.390151311863127,
#  28: 3.41234672740008,
#  29: 3.9832601160171532,
#  30: 4.050020228184945,
#  31: 3.262922321618807,
#  32: 3.433229863273052,
#  33: 3.2790262090405933,
#  34: 3.2799074104645753,
#  35: 3.9832601160171532,
#  36: 4.4134857218147365,
#  37: 3.2822824857292012,
#  38: 4.3509647734713015,
# ...

# %%
sort_orders = sorted(dict_plot_graph.items(), key=lambda x: x[1], reverse=True)

# %%
sort_orders
# Out:
# [(1, 6.488415561512897),
#  (7, 5.8616827626699015),
#  (3, 5.6195150533110185),
#  (8, 5.5021787462271705),
#  (4, 5.398845597126139),
#  (9, 5.3630555594150096),
#  (5, 5.284027001520672),
#  (2, 5.202100106415225),
#  (6, 5.122265426133959),
#  (436, 4.838785143457403),
#  (841, 4.631372178740678),
#  (22, 4.538387901739987),
#  (36, 4.4134857218147365),
#  (38, 4.3509647734713015),
#  (91, 4.271390158217978),
#  (17, 4.232276408674717),
#  (58, 4.2109756811847285),
#  (50, 4.17652626194464),
#  (66, 4.107890587124183),
#  (60, 4.093329915666119),
#  (30, 4.050020228184945),
#  (15, 4.008016339733195),
#  (63, 3.9849608601634303),
#  (29, 3.9832601160171532),
#  (35, 3.9832601160171532),
#  (43, 3.9832601160171532),
#  (18, 3.982646779538257),
#  (69, 3.982459334711237),
#  (25, 3.713324882142705),
#  (9997, 3.6919848007368015),
#  (26, 3.6577577737067153),
#  (16, 3.618784139013056),
#  (12, 3.5736602278943908),
#  (97, 3.570336790983312),
#  (55, 3.552793485258407),
# ...

# %%
Bird_Id = []
Bird_week_trade_score = []
for key, value in sort_orders:
    Bird_Id.append(key)
    Bird_week_trade_score.append(value)

# %%
# for i in Bird_Id:
#     print(str(i)+',')

# %%
dict_BirdID_Rank_Score = dict(zip(sorted_Bird_Ids,zip(sorted_Ranks,sorted_Score)))

# %%
dict_BirdID_Rank_Score
# Out:
# {1: (1, 6.488415561512897),
#  2: (8, 5.202100106415225),
#  3: (3, 5.6195150533110185),
#  4: (5, 5.398845597126139),
#  5: (7, 5.284027001520672),
#  6: (9, 5.122265426133959),
#  7: (2, 5.8616827626699015),
#  8: (4, 5.5021787462271705),
#  9: (6, 5.3630555594150096),
#  10: (79, 3.2548816799852704),
#  11: (35, 3.512563325981266),
#  12: (30, 3.5736602278943908),
#  13: (51, 3.38832664102346),
#  14: (33, 3.5420034052298397),
#  15: (20, 4.008016339733195),
#  16: (29, 3.618784139013056),
#  17: (14, 4.232276408674717),
#  18: (25, 3.982646779538257),
#  19: (90, 3.2032236759401225),
#  20: (75, 3.2697033284809733),
#  21: (61, 3.3126429175573566),
#  22: (10, 4.538387901739987),
#  23: (69, 3.2836397129903334),
#  24: (41, 3.446312789308561),
#  25: (27, 3.713324882142705),
#  26: (28, 3.6577577737067153),
#  27: (49, 3.390151311863127),
#  28: (46, 3.41234672740008),
#  29: (22, 3.9832601160171532),
#  30: (19, 4.050020228184945),
#  31: (77, 3.262922321618807),
# ...

# %%
# for i in dict_BirdID_Rank_Score:
#     print(i, dict_BirdID_Rank_Score[i])

# %%
# x = {1: (2,4), 3: (4,3), 4: (3,2), 2: (1,1), 0: (0,0)}
# {k: v for k, v in sorted(x.items(), key=lambda item: item[1][1])}

# %%
x_sorted_rank = {k: v for k, v in sorted(dict_BirdID_Rank_Score.items(), key=lambda item: item[1][0])}
# print(x_sorted_rank)
# for j in x_sorted_rank:
#     print(j,x_sorted_rank[j])
print(len(x_sorted_rank))
# Out:
# 8478

# %%
bird_id_list = list(x_sorted_rank.keys())

# %%
for i in bird_id_list:
    print(str(i)+',')
# Out:
# 1,
# 7,
# 3,
# 8,
# 4,
# 9,
# 5,
# 2,
# 6,
# 22,
# 36,
# 38,
# 91,
# 17,
# 58,
# 50,
# 66,
# 60,
# 30,
# 15,
# 63,
# 29,
# 35,
# 43,
# 18,
# 69,
# 25,
# 26,
# 16,
# 12,
# 97,
# 55,
# 14,
# 44,
# 11,
# 52,
# 80,
# 40,
# 75,
# 61,
# 24,
# 46,
# 85,
# 96,
# 78,
# 28,
# 79,
# 94,
# 27,
# 82,
# 13,
# 68,
# 51,
# 99,
# 73,
# 70,
# 90,
# 95,
# 54,
# 98,
# 21,
# 41,
# 89,
# 39,
# 65,
# 62,
# 84,
# 56,
# 23,
# 37,
# 34,
# 33,
# 64,
# 49,
# 20,
# 57,
# 31,
# 45,
# 10,
# 48,
# 53,
# 71,
# 77,
# 59,
# 32,
# 88,
# 86,
# 47,
# 93,
# 19,
# 83,
# 42,
# 81,
# 74,
# 76,
# 72,
# 436,
# 841,
# 319,
# 846,
# 404,
# 468,
# 677,
# 108,
# 548,
# 102,
# 866,
# 185,
# 469,
# 643,
# 439,
# 431,
# 657,
# 687,
# 666,
# 448,
# 145,
# 697,
# 408,
# 348,
# 472,
# 323,
# 326,
# 459,
# 453,
# 530,
# 396,
# 217,
# 669,
# 836,
# 752,
# 676,
# 481,
# 624,
# 111,
# 214,
# 281,
# 654,
# 179,
# 251,
# 146,
# 462,
# 293,
# 592,
# 714,
# 176,
# 116,
# 705,
# 503,
# 998,
# 445,
# 400,
# 606,
# 670,
# 455,
# 170,
# 911,
# ...

# %%
x_sorted_rank[1][1]
# Out:
# 6.488415561512897

# %%
#Make dictionary of keys and value

lable = Bird_Id

data = Bird_week_trade_score
# bird_id = list(x_sorted_rank.keys())


# for i in x_sorted_rank:
# #     bird_id.append(x_sorted_rank[i].key)
#     lable.append(x_sorted_rank[i][0])
#     data.append(x_sorted_rank[i][1])
    
# for i in range(3):
#     print(bird_id[i], lable[i], data[i])

# %%
print(len(lable))
# Out:
# 8478

# %%
print(len(data))
# Out:
# 8478

# %%
print(len(bird_id_list))
# Out:
# 8478

# %%
#data for Scatter plot:

# %%
data
# Out:
# [6.488415561512897,
#  5.8616827626699015,
#  5.6195150533110185,
#  5.5021787462271705,
#  5.398845597126139,
#  5.3630555594150096,
#  5.284027001520672,
#  5.202100106415225,
#  5.122265426133959,
#  4.838785143457403,
#  4.631372178740678,
#  4.538387901739987,
#  4.4134857218147365,
#  4.3509647734713015,
#  4.271390158217978,
#  4.232276408674717,
#  4.2109756811847285,
#  4.17652626194464,
#  4.107890587124183,
#  4.093329915666119,
#  4.050020228184945,
#  4.008016339733195,
#  3.9849608601634303,
#  3.9832601160171532,
#  3.9832601160171532,
#  3.9832601160171532,
#  3.982646779538257,
#  3.982459334711237,
#  3.713324882142705,
#  3.6919848007368015,
#  3.6577577737067153,
#  3.618784139013056,
#  3.5736602278943908,
#  3.570336790983312,
#  3.552793485258407,
#  3.5420034052298397,
#  3.5184404794318165,
#  3.512563325981266,
#  3.4985530200112938,
#  3.488621989453283,
#  3.4595345573082943,
#  3.4560285375999067,
#  3.446312789308561,
#  3.433229863273052,
# ...

# %%
#Data for scatter Plot
#[{ x: -10, y: 0 }, { x: 0, y: 10 }, { x: 10, y: 5 }, { x: 0.5, y: 5.5 }]

# %%
bird_id_list
# Out:
# [1,
#  7,
#  3,
#  8,
#  4,
#  9,
#  5,
#  2,
#  6,
#  22,
#  36,
#  38,
#  91,
#  17,
#  58,
#  50,
#  66,
#  60,
#  30,
#  15,
#  63,
#  29,
#  35,
#  43,
#  18,
#  69,
#  25,
#  26,
#  16,
#  12,
#  97,
#  55,
#  14,
#  44,
#  11,
#  52,
#  80,
#  40,
#  75,
#  61,
#  24,
#  46,
#  85,
#  96,
#  78,
#  28,
#  79,
#  94,
#  27,
#  82,
#  13,
#  68,
#  51,
#  99,
#  73,
#  70,
#  90,
#  95,
#  54,
#  98,
#  21,
#  41,
#  89,
#  39,
#  65,
#  62,
#  84,
#  56,
#  23,
#  37,
#  34,
#  33,
#  64,
#  49,
#  20,
#  57,
#  31,
#  45,
#  10,
#  48,
#  53,
#  71,
#  77,
#  59,
#  32,
#  88,
#  86,
#  47,
#  93,
#  19,
#  83,
#  42,
#  81,
#  74,
#  76,
#  72,
#  436,
#  841,
#  319,
#  846,
#  404,
#  468,
#  677,
#  108,
#  548,
#  102,
#  866,
#  185,
#  469,
#  643,
#  439,
#  431,
#  657,
#  687,
#  666,
#  448,
#  145,
#  697,
#  408,
#  348,
#  472,
#  323,
#  326,
#  459,
#  453,
#  530,
#  396,
#  217,
#  669,
#  836,
#  752,
#  676,
#  481,
#  624,
#  111,
#  214,
#  281,
#  654,
# ...

# %%
#Ids: 1-9:
# bird_id_list.index()

for i in bird_id_list:
    if i<10:
        #save_Index
        _ = bird_id_list.index(i)
#         print(bird_id[_],lable[_],data[_])
        print('{','x:',str(lable[_])+',','y:',data[_],'},')
# Out:
# { x: 1, y: 6.488415561512897 },
# { x: 7, y: 5.8616827626699015 },
# { x: 3, y: 5.6195150533110185 },
# { x: 8, y: 5.5021787462271705 },
# { x: 4, y: 5.398845597126139 },
# { x: 9, y: 5.3630555594150096 },
# { x: 5, y: 5.284027001520672 },
# { x: 2, y: 5.202100106415225 },
# { x: 6, y: 5.122265426133959 },

# %%
#Ids: 10-99:
# bird_id.index()

for i in bird_id_list:
    if 9<i<100:
        #save_Index
        _ = bird_id_list.index(i)
#         print(bird_id[_],lable[_],data[_])
        print('{','x:',str(lable[_])+',','y:',data[_],'},')
# Out:
# { x: 436, y: 4.838785143457403 },
# { x: 841, y: 4.631372178740678 },
# { x: 22, y: 4.538387901739987 },
# { x: 36, y: 4.4134857218147365 },
# { x: 38, y: 4.3509647734713015 },
# { x: 91, y: 4.271390158217978 },
# { x: 17, y: 4.232276408674717 },
# { x: 58, y: 4.2109756811847285 },
# { x: 50, y: 4.17652626194464 },
# { x: 66, y: 4.107890587124183 },
# { x: 60, y: 4.093329915666119 },
# { x: 30, y: 4.050020228184945 },
# { x: 15, y: 4.008016339733195 },
# { x: 63, y: 3.9849608601634303 },
# { x: 29, y: 3.9832601160171532 },
# { x: 35, y: 3.9832601160171532 },
# { x: 43, y: 3.9832601160171532 },
# { x: 18, y: 3.982646779538257 },
# { x: 69, y: 3.982459334711237 },
# { x: 25, y: 3.713324882142705 },
# { x: 9997, y: 3.6919848007368015 },
# { x: 26, y: 3.6577577737067153 },
# { x: 16, y: 3.618784139013056 },
# { x: 12, y: 3.5736602278943908 },
# { x: 97, y: 3.570336790983312 },
# { x: 55, y: 3.552793485258407 },
# { x: 14, y: 3.5420034052298397 },
# { x: 44, y: 3.5184404794318165 },
# ...

# %%
#Ids: 100-999:
# bird_id.index()

for i in bird_id:
    if 99<i<1000:
        #save_Index
        _ = bird_id.index(i)
#         print(bird_id[_],lable[_],data[_])
        print('{','x:',str(lable[_])+',','y:',data[_],'},')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-fb132a86818b> in <module>
#       2 # bird_id.index()
#       3
# ----> 4 for i in bird_id:
#       5     if 99<i<1000:
#       6         #save_Index
#
# NameError: name 'bird_id' is not defined

# %%
#Ids: 1000-10000:
# bird_id.index()

for i in bird_id:
    if 999<i<10000:
        #save_Index
        _ = bird_id.index(i)
#         print(bird_id[_],lable[_],data[_])
        print('{','x:',str(lable[_])+',','y:',data[_],'},')
# Out:
# { x: 825, y: 3.6919848007368015 },
# { x: 826, y: 2.5869061114700416 },
# { x: 827, y: 2.5296317176423853 },
# { x: 828, y: 2.443021841065651 },
# { x: 829, y: 2.428175855477807 },
# { x: 830, y: 2.3647143957384236 },
# { x: 831, y: 2.3321236443991755 },
# { x: 832, y: 2.2684032375852508 },
# { x: 833, y: 2.2225291632875237 },
# { x: 834, y: 2.2005541563048423 },
# { x: 835, y: 2.1829913704188004 },
# { x: 836, y: 2.175934891232008 },
# { x: 837, y: 2.1742874521024387 },
# { x: 838, y: 2.1675737378007374 },
# { x: 839, y: 2.1451439375519468 },
# { x: 840, y: 2.138661482440644 },
# { x: 841, y: 2.1242608743011555 },
# { x: 842, y: 2.108027296021948 },
# { x: 843, y: 2.1054915591152934 },
# { x: 844, y: 2.104524423276356 },
# { x: 845, y: 2.099514965507085 },
# { x: 846, y: 2.097870377820636 },
# { x: 847, y: 2.0976608985302136 },
# { x: 848, y: 2.0935335588153308 },
# { x: 849, y: 2.0925382591867896 },
# { x: 850, y: 2.0371616030452206 },
# { x: 851, y: 2.0247086128104845 },
# ...

# %%
import csv
birds_dataset_with_ranks = list()
int_columns = [0, -3, -5, -7]
numeric_columns = [-1, -2, -4, -6, -8]
with open('static/Data/birds_dataset_with_ranks_new.csv') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=';')
    line_count = 0
    for row in csv_reader:
        if line_count == 0:
            print(f'Column names are {", ".join(row)}')
            column_names = row
            line_count += 1
        else:
            for int_element in int_columns:
                row[int_element] = int(row[int_element])
            for numeric_element in numeric_columns:
                row[numeric_element] = float(row[numeric_element])
            birds_dataset_with_ranks.append(row)
            line_count += 1
    print(f'Processed {line_count} lines.')
# Out:
# Column names are bird_id,theme,head,eyes,body,tail,wingLeft,wingRight,feet,beak,trait_score,trait_rank,set_score,set_rank,edition_score,edition_rank,weighted_score,weighted_rank,birds_weighted_normalized_scores,week_trade_score
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-dda43e48f8c9> in <module>
#      13         else:
#      14             for int_element in int_columns:
# ---> 15                 row[int_element] = int(row[int_element])
#      16             for numeric_element in numeric_columns:
#      17                 row[numeric_element] = float(row[numeric_element])
#
# ValueError: invalid literal for int() with base 10: '1,cyberbird,cyberbird,cyberbird,cyberbird,cyberbird,cyberbird,cyberbird,cyberbird,var2,3.898092031672943,4,1.9994714877881563,1,14.350200592323434,1,6.749254703928178,1,20.247764111784527,6.488415561

# %%
bird_id = input('Give bird Id (Max 4 digits): ')
if bird_id == '':
    print("Please give input")
elif(len(bird_id) > 4):
    print("Error! Input more than 4")
    
else:
    print('Bird Id',int(bird_id))
    bird_id = int(bird_id)
# Out:
# Give bird Id (Max 4 digits): 7
# Bird Id 7

# %%
BirdInfo = df.loc[df['bird_id'] == bird_id]

# %%
#Create dictionary
our_dict = dict()
for row_index in range(len(birds_dataset_with_ranks)):
    row = birds_dataset_with_ranks[row_index]
    our_dict[row[0]] = row_index
    
# print(our_dict.keys())

bird_index = bird_id
if bird_index in set(our_dict.keys()):
    bird_row = our_dict[bird_index]
else:
    print('Ups!')

print(bird_row)
# Out:
# 6

# %%
# BirdInfo = bird_id
# T_score = df.loc[df['bird_id'] == bird_id]['trait_score'][1]
# T_rank = df.loc[df['bird_id'] == bird_id]['trait_rank'][1]
# H_score = df.loc[df['bird_id'] == bird_id]['harmony_score'][1]
# H_rank = df.loc[df['bird_id'] == bird_id]['harmony_rank'][1]
# E_score = df.loc[df['bird_id'] == bird_id]['edition_score'][1]
# E_rank = df.loc[df['bird_id'] == bird_id]['edition_rank'][1]
# OA_score = df.loc[df['bird_id'] == bird_id]['weighted_score'][1]
# OA_rank = df.loc[df['bird_id'] == bird_id]['weighted_rank'][1]

# %%
print(f'''
BirdInfo = {bird_id}

T_score = {str(round(df.loc[df['bird_id'] == bird_id]['trait_score'][bird_row],2))}
T_rank = {str(round(df.loc[df['bird_id'] == bird_id]['trait_rank'][bird_row],2))}
H_score = {str(round(df.loc[df['bird_id'] == bird_id]['set_score'][bird_row],2))}
H_rank = {str(round(df.loc[df['bird_id'] == bird_id]['set_rank'][bird_row],2))}
E_score = {str(round(df.loc[df['bird_id'] == bird_id]['edition_score'][bird_row],2))}
E_rank = {str(round(df.loc[df['bird_id'] == bird_id]['edition_rank'][bird_row],2))}
OA_score = {str(round(df.loc[df['bird_id'] == bird_id]['week_trade_score'][bird_row],2))}
OA_rank = {str(round(bird_id_list.index(bird_id) + 1,2))}
''')
# Out:
# BirdInfo = 7
#
# T_score = 3.06
# T_rank = 9
# H_score = 2.0
# H_rank = 3
# E_score = 14.35
# E_rank = 1
# OA_score = 5.86
# OA_rank = 2
